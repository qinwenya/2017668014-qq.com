# %% [markdown]
# # 变量生成
# 通常情况下，我们分析由调查问卷得到的数据时，需要将多个题项进行合并，生成某个变量在特定维度的的值。合并题项的时候，一定要保证题项的方向是一致的。
# ![Snipaste_2023-12-14_11-49-51.png](attachment:Snipaste_2023-12-14_11-49-51.png)]()

# %%
import pandas as pa
import mytools

# %%
数据表 = mytools.读取SPSS数据文件()
数据表.columns

# %%
数据表['认知维度'] = 数据表.
